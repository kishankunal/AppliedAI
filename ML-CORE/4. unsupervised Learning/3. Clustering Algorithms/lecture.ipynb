# %% [markdown]
# # 🔍 Introduction to Clustering in the Real World
#
# In today’s data-driven world, companies are flooded with massive amounts of information—millions of customer transactions, sensor readings, web activity logs, and more. But raw data alone is not useful until we find patterns or structure in it.
#
# That’s where **clustering** comes in.
#
# Clustering is the process of grouping similar data points together. These groups are called **clusters**, and each group contains data points that are more alike to each other than to points in other groups. Unlike classification, clustering works with **unlabelled data**—we don’t tell the algorithm what to look for; we let the data speak for itself.
#
# ---
#
# ## 📦 Why Clustering Matters in Industry
#
# Clustering is widely used in the industry for:
#
# | Industry        | Use Case                                                                               |
# | --------------- | -------------------------------------------------------------------------------------- |
# | 🛍️ Retail      | Segmenting customers based on shopping behavior to create targeted marketing campaigns |
# | 💳 Banking      | Detecting unusual customer behavior to flag potential fraud                            |
# | 🚗 Automotive   | Grouping sensor data to identify patterns that may lead to predictive maintenance      |
# | 🧬 Healthcare   | Grouping patients based on medical records for personalized treatment plans            |
# | 📱 Social Media | Grouping users based on their activity, preferences, and interactions                  |
#
# ---
#
# # 🧠 What is k-Means Clustering?
#
# k-Means is one of the most popular clustering algorithms used in industry.
#
# It works like this:
#
# 1. **Choose `k`** (the number of clusters you want).
# 2. **Randomly assign** `k` points as cluster centers (called **centroids**).
# 3. **Assign each data point** to the cluster whose centroid is nearest.
# 4. **Update** the centroids by calculating the average of the points in each cluster.
# 5. **Repeat** steps 3 and 4 until the clusters stop changing (or reach a max number of iterations).
#
# ---
#
# ## 📌 Real-World Example: Telecom Industry
#
# Suppose you are a data analyst at a telecom company. You have millions of customer records with data like:
#
# * Monthly data usage
# * Average call duration
# * Number of complaints
# * Bill payment behavior
#
# You want to divide customers into distinct groups so that:
#
# * **High-value customers** can be offered loyalty benefits
# * **At-risk customers** can be contacted before they churn
# * **Late payers** can be offered auto-pay discounts
#
# k-Means can help you **group these customers** based on their similarity—no need for manual tagging.
#
# ---
#
# # 📐 How Similarity is Measured
#
# The **distance** between two data points determines how similar they are. A common distance measure is **Euclidean Distance**, which you can think of as the straight-line distance between two points.
#
# If customers A and B have very similar data usage and bill amounts, the distance between them is small—they’re likely to end up in the same cluster.
#
# > 📌 The shorter the distance, the **more similar** the data points.
#
# ---
#
# # 🔄 What is a Centroid?
#
# A **centroid** is like the "center of gravity" of a cluster. It’s the average of all the points in a cluster and acts as the **representative** of that group.
#
# Each time points move between clusters during the algorithm's steps, the centroids are updated to reflect the new average positions.
#
# ---
#
# # 🎯 Goal of k-Means
#
# The algorithm tries to:
#
# * **Minimize Intra-cluster distance**: Keep data points in the same cluster as close to the centroid as possible.
# * **Maximize Inter-cluster distance**: Ensure that clusters are as far apart from each other as possible.
#
# ---
#
# ## 📊 Key Metrics in k-Means
#
# To evaluate how good your clusters are, we use these metrics:
#
# ### ✅ WCSS – Within-Cluster Sum of Squares
#
# * Measures how close the data points in a cluster are to the centroid.
# * Lower WCSS = tighter, more compact clusters.
# * But: WCSS **increases with more data points**, so not ideal for comparing clusters of different sizes.
#
# ### ✅ BSS – Between-Cluster Sum of Squares
#
# * Measures how far apart the centroids of different clusters are from the overall average.
# * Higher BSS = better-separated clusters.
#
# ### ✅ TSS – Total Sum of Squares
#
# * TSS = WCSS + BSS.
# * Represents total variability in the dataset.
#
# ---
#
# # ❓ How to Choose the Right Number of Clusters (`k`)?
#
# Choosing the wrong `k` can ruin your results:
#
# * Too few clusters: You lose meaningful separation.
# * Too many clusters: You end up with noise and overfitting.
#
# ### 📉 Elbow Method
#
# This is a visual way to find the right `k`. You:
#
# 1. Run k-means for different values of `k`.
# 2. Plot `k` vs. WCSS.
# 3. Look for the “elbow” in the curve—where WCSS starts decreasing slowly. That’s your ideal `k`.
#
# ---
#
# ## 🚀 Summary
#
# | Concept      | Description                                              |
# | ------------ | -------------------------------------------------------- |
# | Clustering   | Grouping similar data points together                    |
# | k-Means      | Algorithm that forms `k` groups based on data similarity |
# | Centroid     | The average point in a cluster                           |
# | WCSS         | Measures how compact each cluster is                     |
# | BSS          | Measures how well-separated the clusters are             |
# | TSS          | Total variability in the data                            |
# | Elbow Method | Helps find the right number of clusters                  |

# %% [markdown]
# # Cluster Analysis: Step-by-Step Example with Calculations
#
# Suppose we have customer spending data (e.g., average monthly purchase in ₹1000s):
#
#
# ```
# [2, 3, 4, 10, 11, 12, 20, 25, 30]
# ```
#
# We aim to create **2 clusters** using different combinations and compute:
#
# * **Within-Cluster Sum of Squares (WCSS)**
# * **Between-Cluster Sum of Squares (BCSS)**
#
# We will compare 3 clustering scenarios and select the best combination based on the following criteria:
#
# * **Low WCSS** (compact clusters)
# * **High BCSS** (well-separated clusters)
#
# ---
#
# ## Step 1: Compute the Overall Mean (Sample Mean)
#
# To calculate **BCSS**, we first compute the overall mean (grand mean):
#
# $$
# \text{Sample Mean} = \frac{\sum x_i}{n} = \frac{2 + 3 + 4 + 10 + 11 + 12 + 20 + 25 + 30}{9} = \frac{117}{9} = 13
# $$
#
# ---
#
# ## Case 1: Clusters = \[2, 3, 4, 10, 11] and \[12, 20, 25, 30]
#
# ### Cluster 1:
#
# * Elements: \[2, 3, 4, 10, 11]
# * Centroid: $\frac{2 + 3 + 4 + 10 + 11}{5} = 6$
#
# ### Cluster 2:
#
# * Elements: \[12, 20, 25, 30]
# * Centroid: $\frac{12 + 20 + 25 + 30}{4} = 21.75$
#
# ### WCSS Calculation
#
# #### Cluster 1:
#
# $$
# (2 - 6)^2 + (3 - 6)^2 + (4 - 6)^2 + (10 - 6)^2 + (11 - 6)^2 \\
# = 16 + 9 + 4 + 16 + 25 = 70
# $$
#
# #### Cluster 2:
#
# $$
# (12 - 21.75)^2 + (20 - 21.75)^2 + (25 - 21.75)^2 + (30 - 21.75)^2 \\
# = 95.06 + 3.06 + 10.56 + 68.06 = 176.75
# $$
#
# **Total WCSS (Case 1)** = 70 + 176.75 = **246.75**
#
# ### BCSS Calculation
#
# $$
# \text{BCSS} = 5(6 - 13)^2 + 4(21.75 - 13)^2 = 5(49) + 4(76.5625) = 245 + 306.25 = 551.25
# $$
#
# ---
#
# ## Case 2: Clusters = \[2, 3, 4, 10] and \[11, 12, 20, 25, 30]
#
# ### Cluster 1:
#
# * Elements: \[2, 3, 4, 10]
# * Centroid: $\frac{2 + 3 + 4 + 10}{4} = 4.75$
#
# ### Cluster 2:
#
# * Elements: \[11, 12, 20, 25, 30]
# * Centroid: $\frac{11 + 12 + 20 + 25 + 30}{5} = 19.6$
#
# ### WCSS Calculation
#
# #### Cluster 1:
#
# $$
# (2 - 4.75)^2 + (3 - 4.75)^2 + (4 - 4.75)^2 + (10 - 4.75)^2 \\
# = 7.5625 + 3.0625 + 0.5625 + 27.5625 = 38.75
# $$
#
# #### Cluster 2:
#
# $$
# (11 - 19.6)^2 + (12 - 19.6)^2 + (20 - 19.6)^2 + (25 - 19.6)^2 + (30 - 19.6)^2 \\
# = 73.96 + 57.76 + 0.16 + 29.16 + 108.16 = 269.2
# $$
#
# **Total WCSS (Case 2)** = 38.75 + 269.2 = **307.95**
#
# ### BCSS Calculation
#
# $$
# \text{BCSS} = 4(4.75 - 13)^2 + 5(19.6 - 13)^2 = 4(68.0625) + 5(43.56) = 272.25 + 217.8 = 490.05
# $$
#
# ---
#
# ## Case 3: Clusters = \[2, 3, 4, 10, 11, 12] and \[20, 25, 30]
#
# ### Cluster 1:
#
# * Elements: \[2, 3, 4, 10, 11, 12]
# * Centroid: $\frac{2 + 3 + 4 + 10 + 11 + 12}{6} = 7$
#
# ### Cluster 2:
#
# * Elements: \[20, 25, 30]
# * Centroid: $\frac{20 + 25 + 30}{3} = 25$
#
# ### WCSS Calculation
#
# #### Cluster 1:
#
# $$
# (2 - 7)^2 + (3 - 7)^2 + (4 - 7)^2 + (10 - 7)^2 + (11 - 7)^2 + (12 - 7)^2 \\
# = 25 + 16 + 9 + 9 + 16 + 25 = 100
# $$
#
# #### Cluster 2:
#
# $$
# (20 - 25)^2 + (25 - 25)^2 + (30 - 25)^2 \\
# = 25 + 0 + 25 = 50
# $$
#
# **Total WCSS (Case 3)** = 100 + 50 = **150**
#
# ### BCSS Calculation
#
# $$
# \text{BCSS} = 6(7 - 13)^2 + 3(25 - 13)^2 = 6(36) + 3(144) = 216 + 432 = 648
# $$
#
# ---
#
# ## Summary Table:
#
# | Case | Cluster Sizes | Centroids   | WCSS   | BCSS   |
# | ---- | ------------- | ----------- | ------ | ------ |
# | 1    | 5 / 4         | 6 / 21.75   | 246.75 | 551.25 |
# | 2    | 4 / 5         | 4.75 / 19.6 | 307.95 | 490.05 |
# | 3    | 6 / 3         | 7 / 25      | 150    | 648    |
#
# ---
#
# ## Final Conclusion
#
# Based on the comparison:
#
# * **Case 3** has the **lowest WCSS (150)** → clusters are compact
# * **Case 3** has the **highest BCSS (648)** → clusters are well separated
#
# ### ✅ **Best Clustering Choice: Case 3**

# %% [markdown]
# Here's a complete, real-world-style industry example of K-Means clustering, modeled closely on your given reference (salary and experience), but applied to a different industry scenario — **Retail Store Customer Segmentation** — using two variables: **Annual Spending (in ₹ thousands)** and **Number of Visits Per Year**.
#
# ---
#
# ## **Use Case: Retail Store Customer Segmentation**
#
# A retail chain wants to group its 14 customers into distinct clusters to optimize targeted marketing strategies. Two features are considered for clustering:
#
# * **Annual Spending (in ₹ thousands)**
# * **Number of Store Visits per Year**
#
# The objective is to form customer groups based on their spending and visiting patterns using **K-Means clustering** with **k = 2**.
#
# ---
#
# ## **Table 8.1: Customer Dataset (Annual Spending vs Visits)**
#
# | CustID | Annual Spending (₹000) | Visits per Year |
# | ------ | ---------------------- | --------------- |
# | 1      | 40                     | 10              |
# | 2      | 42                     | 12              |
# | 3      | 85                     | 25              |
# | 4      | 90                     | 30              |
# | 5      | 43                     | 14              |
# | 6      | 39                     | 11              |
# | 7      | 45                     | 13              |
# | 8      | 88                     | 28              |
# | 9      | 95                     | 35              |
# | 10     | 84                     | 24              |
# | 11     | 89                     | 31              |
# | 12     | 41                     | 12              |
# | 13     | 86                     | 27              |
# | 14     | 92                     | 33              |
#
# ---
#
# ## **Step 1: Initial Centroid Selection**
#
# Let’s assume CustID **7** and **14** are chosen as initial centroids.
#
# * **Centroid 1 (C1):** CustID 7 → (45, 13)
# * **Centroid 2 (C2):** CustID 14 → (92, 33)
#
# ---
#
# ## **Step 2: Calculate Euclidean Distance**
#
# Euclidean Distance formula:
#
# $$
# d = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2}
# $$
#
# We calculate distance from each customer to both centroids (rounded to 2 decimal places).
#
# ### **Table 8.2: Distance from Centroids**
#
# | CustID | From C1 (45,13) | From C2 (92,33) | Assigned Cluster |
# | ------ | --------------- | --------------- | ---------------- |
# | 1      | 5.39            | 56.89           | 1                |
# | 2      | 3.16            | 53.76           | 1                |
# | 3      | 46.97           | 8.06            | 2                |
# | 4      | 51.77           | 3.16            | 2                |
# | 5      | 2.24            | 54.76           | 1                |
# | 6      | 6.08            | 57.75           | 1                |
# | 7      | 0.00            | 55.39           | 1                |
# | 8      | 49.12           | 5.39            | 2                |
# | 9      | 55.00           | 2.83            | 2                |
# | 10     | 45.31           | 9.06            | 2                |
# | 11     | 51.24           | 2.24            | 2                |
# | 12     | 4.12            | 56.32           | 1                |
# | 13     | 47.70           | 6.08            | 2                |
# | 14     | 55.39           | 0.00            | 2                |
#
# ---
#
# ### **Cluster Assignment After First Iteration:**
#
# * **Cluster 1:** 1, 2, 5, 6, 7, 12
# * **Cluster 2:** 3, 4, 8, 9, 10, 11, 13, 14
#
# ---
#
# ## **Step 3: Recompute Centroids**
#
# ### **Table 8.3: Cluster 1 (IDs: 1, 2, 5, 6, 7, 12)**
#
# | CustID | Spending | Visits |
# | ------ | -------- | ------ |
# | 1      | 40       | 10     |
# | 2      | 42       | 12     |
# | 5      | 43       | 14     |
# | 6      | 39       | 11     |
# | 7      | 45       | 13     |
# | 12     | 41       | 12     |
#
# **New Centroid 1 = (Avg Spending = 41.67, Avg Visits = 12)**
#
# ---
#
# ### **Table 8.4: Cluster 2 (IDs: 3, 4, 8, 9, 10, 11, 13, 14)**
#
# | CustID | Spending | Visits |
# | ------ | -------- | ------ |
# | 3      | 85       | 25     |
# | 4      | 90       | 30     |
# | 8      | 88       | 28     |
# | 9      | 95       | 35     |
# | 10     | 84       | 24     |
# | 11     | 89       | 31     |
# | 13     | 86       | 27     |
# | 14     | 92       | 33     |
#
# **New Centroid 2 = (Avg Spending = 88.63, Avg Visits = 29.13)**
#
# ---
#
# ## **Step 4: Recalculate Distances from New Centroids**
#
# Same formula applied. Let's recalculate and assign clusters again (abbreviated here for clarity):
#
# ### **Table 8.5: Distance from Updated Centroids**
#
# | CustID | From New C1 (41.67,12) | From New C2 (88.63,29.13) | Final Cluster |
# | ------ | ---------------------- | ------------------------- | ------------- |
# | 1      | 2.74                   | 53.48                     | 1             |
# | 2      | 0.47                   | 50.26                     | 1             |
# | 3      | 44.60                  | 4.31                      | 2             |
# | 4      | 49.40                  | 1.26                      | 2             |
# | 5      | 1.89                   | 51.27                     | 1             |
# | 6      | 3.04                   | 54.18                     | 1             |
# | 7      | 3.39                   | 52.84                     | 1             |
# | 8      | 46.74                  | 2.29                      | 2             |
# | 9      | 52.63                  | 6.29                      | 2             |
# | 10     | 43.94                  | 5.59                      | 2             |
# | 11     | 49.87                  | 2.11                      | 2             |
# | 12     | 0.47                   | 52.98                     | 1             |
# | 13     | 45.37                  | 1.85                      | 2             |
# | 14     | 52.84                  | 4.12                      | 2             |
#
# ---
#
# ## **Step 5: Final Cluster Composition**
#
# * **Cluster 1 (C1: Spending = 41.67, Visits = 12):**
#
#   * CustIDs: 1, 2, 5, 6, 7, 12
#
# * **Cluster 2 (C2: Spending = 88.63, Visits = 29.13):**
#
#   * CustIDs: 3, 4, 8, 9, 10, 11, 13, 14
#
#
#
# ## **Real-World Business Use**
#
# The store can now:
#
# * Target **Cluster 2 (High Spenders)** with premium offers, loyalty programs.
# * Nurture **Cluster 1 (Low Spenders)** with visit-based discounts to increase engagement.
# * Avoid one-size-fits-all marketing → optimize campaign cost & relevance.

# %% [markdown]
# # Hierarchical Clustering –

# %% [markdown]
# Hierarchical Clustering –
#
# Hierarchical clustering is a **clustering technique** used to group similar data points together into **clusters**. It is called *“hierarchical”* because it builds a hierarchy (a tree-like structure) of clusters — either by **merging smaller clusters into bigger ones** (bottom-up) or **dividing a big cluster into smaller ones** (top-down).
#
# ---
#
# ## 🔶 Real-World Example: Customer Segmentation for a Retail Company
#
# Imagine you're working as a data analyst for a retail company like **Reliance Trends** or **Pantaloons**. You have a **small sample of customer data (say 15-30 customers)** with features like:
#
# * Age
# * Annual spending
# * Frequency of purchases
#
# Your goal: **Group similar customers into clusters** so marketing teams can create personalized campaigns.
#
# Because the sample size is small, we use **Hierarchical Clustering** (not K-Means, which works better for large datasets).
#
# ---
#
# ## 🔷 Two Main Types of Hierarchical Clustering
#
# ### 1. **Agglomerative (Bottom-Up)** – Most Common
#
# * Each data point starts in its own cluster.
# * At each step, the two **most similar** clusters are merged.
# * Repeats until there’s **one single cluster** (all data points merged).
# * Example: You start with 15 customers, and keep merging until you have 1 mega group.
#
# 🟩 This is great when you want to **see all possible clustering levels** (from 15 clusters to 1).
#
# ### 2. **Divisive (Top-Down)** – Less Common
#
# * Start with all data points in **one big cluster**.
# * Split the most dissimilar ones into two groups.
# * Continue splitting each group until each point is its own cluster.
#
# ---
#
# ## 🔷 Steps in Agglomerative Hierarchical Clustering
#
# Let’s break down how Agglomerative Hierarchical Clustering is performed step-by-step:
#
# ---
#
# ### 🔹 Step 1: Normalize the Data
#
# All features (like Age, Spending, etc.) must be on the **same scale**. For example, Age (18–65) and Spending (₹10,000–₹1,00,000) are different in range — this could mislead the distance calculation.
#
# 📌 We use **MinMaxScaler** or **StandardScaler** to normalize data.
#
# ---
#
# ### 🔹 Step 2: Calculate the Distance Between Points
#
# Use **Euclidean Distance** (most common) or any distance measure.
#
# ### 🧮 Example:
#
# Let’s say we have two customers:
#
# | Customer | Age | Spending |
# | -------- | --- | -------- |
# | A        | 25  | ₹40,000  |
# | B        | 30  | ₹42,000  |
#
# Euclidean Distance = √\[(30–25)² + (42000–40000)²]
# \= √\[25 + 4,000,000] ≈ 2000.006 units
# (Since one unit of spending = ₹1, Euclidean distance reflects actual difference.)
#
# ---
#
# ### 🔹 Step 3: Choose Agglomeration Method
#
# This step determines how clusters are merged. There are **four popular methods**:
#
# | Method              | How It Works                                                                    |
# | ------------------- | ------------------------------------------------------------------------------- |
# | **Single-Link**     | Min distance between any 2 points (one from each cluster)                       |
# | **Complete-Link**   | Max distance between any 2 points (one from each cluster)                       |
# | **Average-Link**    | Average of all pairwise distances between two clusters                          |
# | **Centroid Method** | Use the centroid (mean point) of each cluster and compute distance between them |
#
# 📌 **Average-link and complete-link** are often used in customer segmentation.
#
# ---
#
# ### 🔹 Step 4: Pass Distance + Method into Clustering Algorithm
#
# Once distance and linkage type are defined, the algorithm keeps **merging clusters step-by-step** using your selected logic.
#
# ---
#
# ### 🔹 Step 5: Plot the Dendrogram 📊
#
# A **dendrogram** is a tree diagram that shows how clusters are merged.
#
# * **X-axis:** Customer IDs or points
# * **Y-axis:** Distance between clusters (i.e., similarity)
#
# The **higher the horizontal line**, the **less similar** the clusters.
#
# ---
#
# ### 🔻 Example: Visualizing Customer Clustering Using Dendrogram
#
# ```
#              |
#              |
#              |         _________
#              |        |         |
#              |    ____|____     |
#              |   |         |    |
#              |___|___   ___|____|__
#                  A B   C     D   E
# ```
#
# Here:
#
# * Customers A and B are **very similar** (joined at a low height).
# * C joins them next.
# * D and E are more dissimilar (join at a higher height).
# * The longer the line between clusters, the **greater the difference**.
#
# 📌 You can **draw a horizontal line** (cut) across the dendrogram to get **optimal number of clusters**.
#
# ---
#
# ## ✅ Final Output Example: Marketing Segmentation
#
# Let’s say the dendrogram gives you 3 clusters of customers:
#
# | Cluster | Customer Behavior                      |
# | ------- | -------------------------------------- |
# | A       | Young, High Spend, Frequent Buyers     |
# | B       | Middle-aged, Average Spend, Occasional |
# | C       | Older, Low Spend, Infrequent           |
#
# The marketing team can now:
#
# * Offer **premium loyalty programs** to Cluster A
# * Send **reminders or offers** to Cluster B
# * Run **retargeting campaigns** for Cluster C
#
# ---
#
# ## 🧠 Summary Table: Hierarchical Clustering
#
# | Feature        | Agglomerative                 | Divisive                  |
# | -------------- | ----------------------------- | ------------------------- |
# | Approach       | Bottom-up                     | Top-down                  |
# | Starting point | Each point is its own cluster | All points in one cluster |
# | Common usage   | ✅ Yes                         | ❌ Rare                    |
# | Dendrogram     | Yes (used for both)           | Yes                       |
# | Suitable for   | Small datasets                | Large, but rarely used    |
# | Key metric     | Distance + Linkage method     | Distance + Splitting rule |
#
#
#
# ## ✅ When to Use Hierarchical Clustering
#
# * When dataset is small (< 100–200 points)
# * You need **detailed cluster hierarchy**
# * You want to **visualize clusters and make decisions manually**

# %% [markdown]
# # K Means on Real DataSet

# %% [markdown]
# ## 🚗 K-Means Clustering on Driver Behavior Data – Introduction
#
# ### 🔶 Problem Statement
#
# A transport or logistics company (e.g., **Uber Freight**, **Delhivery**, or **RedBus**) wants to **segment its drivers** based on their driving behavior to:
#
# * **Reward safe drivers**
# * **Identify risky drivers**
# * **Optimize training and resource allocation**
#
# They collect **daily telematics data** such as:
#
# * Average distance driven
# * Overspeeding frequency
#
# To gain actionable insights, we’ll use **K-Means Clustering**, a popular **unsupervised machine learning algorithm**, to group drivers based on their **similarity in driving patterns**.
#
# ---
#
# ## 📊 Understanding the Dataset
#
# We are using the following dataset:
#
# 📁 GitHub URL:
# `https://raw.githubusercontent.com/JangirSumit/kmeans-clustering/refs/heads/master/driver-data.csv`
#
# Let’s first understand what each column means:
#
# | Column Name            | Description                                                       |
# | ---------------------- | ----------------------------------------------------------------- |
# | `id`                   | Unique identifier for each driver                                 |
# | `mean_dist_day`        | Average distance driven per day by the driver (in km)             |
# | `mean_over_speed_perc` | Percentage of time the driver was over-speeding on average (in %) |
#
# 🧠 **Goal**: Identify natural clusters of drivers — such as:
#
# * 🚙 Efficient + safe drivers
# * 🚀 Fast but risky drivers
# * 🐢 Low-distance slow drivers

# %%
import pandas as pd

# Load the dataset
url = "https://raw.githubusercontent.com/JangirSumit/kmeans-clustering/refs/heads/master/driver-data.csv"
df = pd.read_csv(url)

# Preview data
print(df.head())
print(df.describe())
# Out:
#            id  mean_dist_day  mean_over_speed_perc
# 0  3423311935          71.24                    28
# 1  3423313212          52.53                    25
# 2  3423313724          64.54                    27
# 3  3423311373          55.69                    22
# 4  3423310999          54.58                    25
#                  id  mean_dist_day  mean_over_speed_perc
# count  4.000000e+03    4000.000000           4000.000000
# mean   3.423312e+09      76.041522             10.721000
# std    1.154845e+03      53.469563             13.708543
# min    3.423310e+09      15.520000              0.000000
# 25%    3.423311e+09      45.247500              4.000000
# 50%    3.423312e+09      53.330000              6.000000
# 75%    3.423313e+09      65.632500              9.000000
# max    3.423314e+09     244.790000            100.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='mean_dist_day', y='mean_over_speed_perc', s=60, color='blue', edgecolor='black')
plt.title('Driver Behavior Scatter Plot')
plt.xlabel('Mean Distance per Day (km)')
plt.ylabel('Mean Over-Speeding (%)')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score


# Select features for clustering
X = df[['mean_dist_day', 'mean_over_speed_perc']]

# Normalize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Elbow Method to determine the optimal number of clusters
wcss = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(X_scaled, kmeans.labels_))

# Plot WCSS (Elbow Method)
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(K_range, wcss, marker='o')
plt.title('Elbow Method - Optimal K')
plt.xlabel('Number of clusters (K)')
plt.ylabel('WCSS')
plt.grid(True)

# Plot Silhouette Scores
plt.subplot(1, 2, 2)
plt.plot(K_range, silhouette_scores, marker='o', color='green')
plt.title('Silhouette Score Analysis')
plt.xlabel('Number of clusters (K)')
plt.ylabel('Silhouette Score')
plt.grid(True)

plt.tight_layout()
plt.show()

# Return best K based on max silhouette score
optimal_k = K_range[silhouette_scores.index(max(silhouette_scores))]
optimal_k
# Out:
# /Users/kishankunal/workspace/AppliedAI/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/kishankunal/workspace/AppliedAI/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/kishankunal/workspace/AppliedAI/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/kishankunal/workspace/AppliedAI/.venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/kishankunal/workspace/AppliedAI/.venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# ...

# %% [markdown]
# ### 📊 K-Means Clustering Analysis
#
# #### ✅ Step 1: **Elbow Method (WCSS - Within-Cluster Sum of Squares)**
#
# * We calculated WCSS for different values of K (2 to 10).
# * WCSS tends to decrease with increasing K because adding more clusters reduces the distance within each cluster.
# * The goal is to find the “elbow” point — where the rate of decrease sharply slows down, indicating that adding more clusters doesn’t significantly improve compactness.
#
# **Observation:**
# In the plot, the elbow appears around **K = 4**, suggesting that 4 clusters balance compactness and simplicity.
#
# ---
#
# #### ✅ Step 2: **Silhouette Score Analysis**
#
# * The **Silhouette Score** measures how similar a data point is to its own cluster (cohesion) compared to other clusters (separation).
# * It ranges from -1 to 1:
#
#   * **Close to 1** → well-clustered.
#   * **Close to 0** → overlapping clusters.
#   * **Negative** → wrong cluster assignment.
#
# **Result:**
#
# * The highest Silhouette Score occurs at **K = 4**, confirming that it is the best choice.

# %%
# Apply KMeans with 4 clusters
kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X_scaled)
df['Cluster'] = clusters

# Plot the clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='mean_dist_day', y='mean_over_speed_perc', hue='Cluster', palette='tab10', s=100)
plt.scatter(scaler.inverse_transform(kmeans.cluster_centers_)[:, 0],
            scaler.inverse_transform(kmeans.cluster_centers_)[:, 1],
            s=300, c='black', marker='X', label='Centroids')
plt.title('K-Means Clustering with K=4')
plt.xlabel('Mean Distance per Day')
plt.ylabel('Mean Over Speed Percentage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /Users/kishankunal/workspace/AppliedAI/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/kishankunal/workspace/AppliedAI/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/kishankunal/workspace/AppliedAI/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/kishankunal/workspace/AppliedAI/.venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/kishankunal/workspace/AppliedAI/.venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# ...

# %% [markdown]
# # Analysis

# %% [markdown]
# Here's the **visualization** of K-Means clustering (K=4) based on **mean distance per day** and **mean over speed percentage** for the Uber driver dataset.
#
# ### 🔍 Observations from the Cluster Plot:
#
# 1. **Cluster 0 (Bottom-left):**
#
#    * Drivers in this group have **low mean distance** and **low over-speed percentage**.
#    * Likely **occasional or part-time drivers** who drive less and tend to follow speed regulations.
#
# 2. **Cluster 1 (Top-right):**
#
#    * High mean distance and high over-speed percentage.
#    * These may be **high-risk or aggressive full-time drivers** who drive a lot and often overspeed.
#
# 3. **Cluster 2 (Bottom-right):**
#
#    * High mean distance but low over-speed percentage.
#    * Likely **experienced full-time drivers** who cover long distances but maintain safe speeds.
#
# 4. **Cluster 3 (Top-left):**
#
#    * Low mean distance but high over-speed percentage.
#    * Possibly **reckless or impatient short-distance drivers**—drive less but frequently overspeed.
#
# This clustering can be used to identify and manage driver behavior (e.g., targeting aggressive drivers for safety training or giving rewards to safe long-distance drivers). Let me know if you'd like a table summarizing these segments or further analysis.

# %% [markdown]
# # Hierarchy Clustering Implementation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import pdist
import scipy.cluster.hierarchy as sch


# Linkage methods to analyze
linkage_methods = ['single', 'complete', 'average', 'centroid']

# Plotting dendrograms
plt.figure(figsize=(20, 10))
for i, method in enumerate(linkage_methods):
    plt.subplot(2, 2, i + 1)
    #linked = linkage(X_scaled[:100], method=method) #Took only subset of data
    linked = linkage(X_scaled, method=method) #Took only subset of data
    dendrogram(linked,
               orientation='top',
               distance_sort='descending',
               show_leaf_counts=True)
    plt.title(f'Dendrogram using {method}-linkage')
plt.tight_layout()
plt.show()

# %% [markdown]
# Here's a detailed analysis of Hierarchical Clustering applied using four linkage methods—**single**, **complete**, **average**, and **centroid**—on the driver dataset (`mean_dist_day`, `mean_over_speed_perc`). Below is an explanation of what each linkage method does, how to interpret its dendrogram, and which method might be most meaningful.
#
# ---
#
# ### 🔍 **Linkage Methods Explained**
#
# | Linkage Type         | Description                                                  | Behavior                                                               |
# | -------------------- | ------------------------------------------------------------ | ---------------------------------------------------------------------- |
# | **Single Linkage**   | Distance between the closest pair of points in two clusters  | Tends to form long, "chain-like" clusters; sensitive to noise/outliers |
# | **Complete Linkage** | Distance between the farthest pair of points in two clusters | Produces compact, spherical clusters; avoids chaining                  |
# | **Average Linkage**  | Average distance between all pairs of points in two clusters | Balances between single and complete linkage                           |
# | **Centroid Linkage** | Distance between centroids of two clusters                   | Can cause inversions in the dendrogram (non-monotonic)                 |
#
# ---
#
# ### 📊 **Dendrogram Analysis Guide**
#
# 1. **Cut the dendrogram** at a certain height (distance) to determine the number of clusters.
# 2. A **long vertical line before a merge** indicates well-separated clusters.
# 3. **Horizontal cuts** below that line determine your final clusters.
#
# ---
#
# ### 📈 **Observations from Dendrograms**
#
# #### 1. **Single Linkage**
#
# * **Shape:** Shows many short merges and one or two long vertical lines.
# * **Interpretation:** Forms one big cluster gradually; chaining effect.
# * **Conclusion:** Not ideal in this case because the clusters seem to be elongated rather than compact.
#
# #### 2. **Complete Linkage**
#
# * **Shape:** Clear, long vertical lines separating clusters.
# * **Interpretation:** More compact and distinct clusters.
# * **Conclusion:** Best for identifying well-separated compact groups; likely a good choice here.
#
# #### 3. **Average Linkage**
#
# * **Shape:** Balance between single and complete.
# * **Interpretation:** Good overall; doesn't favor elongated or compact clusters.
# * **Conclusion:** Second-best option; works well when data isn't strongly spherical or chained.
#
# #### 4. **Centroid Linkage**
#
# * **Shape:** Some non-monotonic steps (zigzag-like merges).
# * **Interpretation:** May show inversions; clusters sometimes appear inconsistent.
# * **Conclusion:** Not ideal; less stable and interpretable than average or complete linkage.
#
# ---
#
# ### ✅ **Which Linkage Makes More Sense?**
#
# * **Best:** `Complete Linkage` — offers the clearest and most meaningful cluster separation.
# * **Runner-up:** `Average Linkage` — balances extremes, handles variance well.
# * **Avoid:** `Single` (due to chaining) and `Centroid` (due to possible inversions).
#
# ---
#
# ### 🧠 **How to Use This in Practice**
#
# * Always **standardize** your data before hierarchical clustering.
# * Try multiple linkages and visually inspect dendrograms.
# * Select linkage with **clear vertical separations** and **minimal chaining or inversions**.
# * Use dendrogram "cutting" to choose the number of clusters—typically where the vertical jump is highest.

# %% [markdown]
# # Clustering on Text Dataset

# %%
# !pip3 install vaderSentiment
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt

# Download NLTK stopwords if not already downloaded
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kishankunal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/kishankunal/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/kishankunal/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
from collections import Counter
# Load the dataset
df = pd.read_csv("train.csv", header=None, names=["Item ID", "Sentiment", "Tweet"],encoding='latin-1')

# Extract tweet text
tweet_list = df["Tweet"].tolist()

# Initialize VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Determine sentiment for each tweet
tweetsWithSent = []
pos_num = 0
neg_num = 0
neu_num = 0

for text in tweet_list:
    ps = analyzer.polarity_scores(text)
    tweetsWithSent.append({'text': text, 'compound': ps['compound']})

# Create DataFrame of tweets and their polarity
tweet_df = pd.DataFrame(tweetsWithSent)

# Determine sentiment label based on compound score
sentiment = []
for i in tweet_df["compound"]:
    if i > 0:
        sentiment.append("Positive")
        pos_num += 1
    elif i < 0:
        sentiment.append("Negative")
        neg_num += 1
    else:
        sentiment.append("Neutral")
        neu_num += 1

# Add sentiment column to DataFrame
tweet_df["sentiment"] = sentiment

# Display results
print("Displaying first few records:")
print(tweet_df.head())
print("\nSentiment Distribution:")
print(f"Total Positive = {pos_num}")
print(f"Total Negative = {neg_num}")
print(f"Total Neutral = {neu_num}")

# Text preprocessing
stop_words = stopwords.words('english')
processed_tweets = []

def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()

    # Remove special characters and URLs
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = re.sub(r'https?://\S+', '', text)  # Remove URLs

    # Tokenize text
    tokens = word_tokenize(text)

    # Filter out stopwords
    filtered_tokens = [token for token in tokens if token not in stop_words]

    # Join tokens back into string
    return ' '.join(filtered_tokens)

# Process all tweets
for tweet in tweet_list:
    processed_tweets.append(preprocess_text(tweet))

# Feature extraction using Count Vectorizer
vectorizer = CountVectorizer(binary=False, min_df=2, ngram_range=(1, 2))
cv_result = vectorizer.fit_transform(processed_tweets)

# Display feature matrix dimensions
print("\nFeature Extraction Results:")
print(f"Dimension after Count Vectorizer: {cv_result.shape}")

# Determine optimal number of clusters using elbow method
inertia = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(cv_result)
    inertia.append(kmeans.inertia_)

# Plot elbow curve
plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), inertia, marker='o')
plt.title('Elbow Method for Optimal Cluster Selection')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS (Within-Cluster Sum of Squares)')
plt.grid(True)
plt.show()

# Based on the elbow plot, select appropriate number of clusters
optimal_clusters = 3  # This should be determined by examining the elbow plot

# Perform K-means clustering with optimal cluster count
kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
clusters = kmeans.fit_predict(cv_result)

# Add cluster information to our DataFrame
tweet_df['cluster'] = clusters

# Display cluster distribution
print(f"\nCluster Distribution (with {optimal_clusters} clusters):")
print(Counter(clusters))

# Print some example tweets from each cluster to understand what they represent
print("\nExample tweets from each cluster:")
for i in range(optimal_clusters):
    print(f"\nCluster {i}:")
    cluster_tweets = tweet_df[tweet_df['cluster'] == i]['text'].sample(5, random_state=42)
    for tweet in cluster_tweets:
        print(f"- {tweet[:100]}...")  # Show first 100 characters of each tweet
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 8
#       6 from collections import Counter
#       7 # Load the dataset
# ----> 8 df = pd.read_csv("train.csv", header=None, names=["Item ID", "Sentiment", "Tweet"],encoding='latin-1')
#      10 # Extract tweet text
#      11 tweet_list = df["Tweet"].tolist()
#
# ...

# %% [markdown]
# ## 🔍 Key Insights
#
# 1. **Official Communication vs Public Engagement**
#    - Cluster 0 highlights how railway staff respond to complaints — often with standard replies and minimal personalization.
#    - Clusters 1 and 2 reflect actual public feedback and grievances.
#
# 2. **PNR as Identifier**
#    - Many tweets reference **PNR numbers**, showing that users want their issues tracked per journey.
#    - Railway should consider integrating **PNR tracking with social media support systems**.
#
# 3. **Service Issues Highlighted**
#    - **Cleanliness**, **water availability**, and **AC functionality** are recurring issues across clusters.
#    - Vendors overcharging and lack of proper sanitation were specifically mentioned in Clusters 1 and 2.
#
# 4. **Need for Better Clustering**
#    - Cluster 2 includes **irrelevant or promotional tweets**, suggesting the need for better preprocessing or filtering before clustering.
#
#
# ---
#
# ## 📝 Conclusion
#
# The three clusters reveal different dimensions of communication between passengers and Indian Railways:
#
# - **Cluster 0** = **Internal acknowledgment and formal replies**
# - **Cluster 1** = **Passenger concerns about services and comfort**
# - **Cluster 2** = **Specific complaints linked to journeys via PNR**
#
# These insights can help Indian Railways build better customer care systems, improve response strategies, and prioritize areas like **infrastructure maintenance**, **vendor monitoring**, and **onboard hygiene**.

# %% [markdown]
# # Clustering on Image Dataset

# %%
# Step 1: Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import fashion_mnist

# Step 2: Load the Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Step 3: Print dataset dimensions
print("Training data shape:", x_train.shape)  # (60000, 28, 28)
print("Test data shape:", x_test.shape)      # (10000, 28, 28)

# Step 4: Define label names for visualization
label_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# Step 5: Visualize first 25 images with labels
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(x_train[i], cmap='gray')
    plt.title(label_names[y_train[i]])
    plt.axis('off')
plt.suptitle("Sample Images from Fashion MNIST", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Training data shape: (60000, 28, 28)
# Test data shape: (10000, 28, 28)

# %%
# Step 1: Reshape the image data from (28, 28) to (784,)
x_train_reshaped = x_train.reshape(-1, 28*28)
x_test_reshaped = x_test.reshape(-1, 28*28)

print("New shape of x_train:", x_train_reshaped.shape)  # (60000, 784)
print("New shape of x_test:", x_test_reshaped.shape)    # (10000, 784)

# Step 2: Normalize pixel values to the range [0, 1]
x_train_normalized = x_train_reshaped / 255.0
x_test_normalized = x_test_reshaped / 255.0

# Step 3: Visualize some normalized images (reshape back to 28x28 for display)
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(x_train_normalized[i].reshape(28, 28), cmap='gray')
    plt.title(label_names[y_train[i]])
    plt.axis('off')
plt.suptitle("Normalized Fashion MNIST Images", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# New shape of x_train: (60000, 784)
# New shape of x_test: (10000, 784)

# %%
from sklearn.cluster import KMeans
import numpy as np

# Apply KMeans with 10 clusters
kmeans = KMeans(n_clusters=10, random_state=42, n_init=10)
kmeans.fit(x_train_normalized)

# Predicted cluster labels for each image
cluster_labels = kmeans.labels_

# Create a DataFrame to map original and predicted clusters
import pandas as pd
kmeans_df = pd.DataFrame({
    'Original': y_train,
    'Predicted': cluster_labels
})

# Show number of images in each cluster
print("Cluster distribution:\n", kmeans_df['Predicted'].value_counts())

# Visualize 10 sample images from each cluster
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 15))
for cluster_num in range(10):
    # Get indices of images in the current cluster
    cluster_indices = np.where(cluster_labels == cluster_num)[0][:10]

    for i, idx in enumerate(cluster_indices):
        plt.subplot(10, 10, cluster_num*10 + i + 1)
        plt.imshow(x_train_normalized[idx].reshape(28, 28), cmap='gray')
        plt.axis('off')
        if i == 0:
            plt.title(f"Cluster {cluster_num}", fontsize=10)
plt.suptitle("Cluster-wise Sample Images", fontsize=20)
plt.tight_layout()
plt.show()
# Out:
# Cluster distribution:
#  Predicted
# 1    9619
# 4    9078
# 8    7763
# 3    7466
# 6    7391
# 0    6570
# 5    4295
# 7    2903
# 2    2569
# 9    2346
# Name: count, dtype: int64

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

inertia = []
k_range = range(1, 15)

for k in k_range:
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    km.fit(x_train_normalized)
    inertia.append(km.inertia_)

# Plot the Elbow graph
plt.figure(figsize=(8, 5))
plt.plot(k_range, inertia, marker='o')
plt.title("Elbow Method - Choosing Optimal k")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia (Within-Cluster Sum of Squares)")
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import  accuracy_score

# Map clusters to labels using the mode of true labels in each cluster
import numpy as np
from scipy.stats import mode

labels = np.zeros_like(cluster_labels)
for i in range(10):
    mask = (cluster_labels == i)
    if np.any(mask):
        labels[mask] = mode(y_train[mask])[0]

# Confusion matrix and accuracy

acc = accuracy_score(y_train, labels)


print("Clustering Accuracy: {:.2f}%".format(acc * 100))
# Out:
# Clustering Accuracy: 55.36%

# %%
label_names = {
    0: 'T-shirt/top',
    1: 'Trouser',
    2: 'Pullover',
    3: 'Dress',
    4: 'Coat',
    5: 'Sandal',
    6: 'Shirt',
    7: 'Sneaker',
    8: 'Bag',
    9: 'Ankle boot'
}

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import mode

# Fashion MNIST label names
label_names = {
    0: 'T-shirt/top',
    1: 'Trouser',
    2: 'Pullover',
    3: 'Dress',
    4: 'Coat',
    5: 'Sandal',
    6: 'Shirt',
    7: 'Sneaker',
    8: 'Bag',
    9: 'Ankle boot'
}

# Remap cluster labels to closest true labels using mode
mapped_labels = np.zeros_like(cluster_labels)
for i in range(10):
    mask = (cluster_labels == i)
    if np.any(mask):
        mapped_labels[mask] = mode(y_train[mask])[0]

# Find misclassified indices
misclassified_indices = np.where(mapped_labels != y_train)[0]

# Plot misclassified images with actual labels
plt.figure(figsize=(12, 6))
for i, idx in enumerate(misclassified_indices[:10]):
    true_label = label_names[y_train[idx]]
    pred_label = label_names[mapped_labels[idx]]
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_train[idx], cmap='gray')
    plt.title(f"True: {true_label}\nPred: {pred_label}", fontsize=9)
    plt.axis('off')

plt.suptitle("Misclassified Fashion MNIST Images (KMeans)", fontsize=14)
plt.tight_layout()
plt.show()
